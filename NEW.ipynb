# %%
#global and local variables
x = 10
def change():
    global x
    x = x+5
    print("the value of x in function is:",x)
print ("before calling of function the value is",x)
change()
print("after function calling the value of x is changed as we have given the privilige:",x)
# Out:
# before calling of function the value is 10
# the value of x in function is: 15
# after function calling the value of x is changed as we have given the privilige: 15

# %%
add = lambda x,y: x+y

# %%
r = add(6,8)
print(r)
# Out:
# 14

# %%
#factorial using lambda
factorial = lambda y: y*factorial(y-1) if y>0 else 1
factorial(5)
# Out:
# 120

# %%
x = input().split()
y = map(int,x)
y = list(y)
print(y)
# Out:
# 1 2 3 4
# [1, 2, 3, 4]

# %%
x = list(map(int,input().split()))
print (list(map(lambda x: True if x%2==0 else False,x)))
# Out:
# 1 2 3 4 5 6
# [False, True, False, True, False, True]

# %%
x = list(map(int,input().split()))
print (list(map(lambda x: )))

# %%
import math
def func(n, check=2):
    sq = math.sqrt(n)
    if n%check==0:
        print("Not Prime")
        
    elif check > sq:
        print("Prime number")
        
        
        
    func(n,check=check+1)
# Out:
#   File "<ipython-input-27-0ba40fdbbe24>", line 9
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
func(8)
# Out:
# Not Prime
# Prime number
# Not Prime
# Prime number
# Prime number
# Prime number
# Not Prime
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# Prime number
# ...

# %%
func(8)
# Out:
# Prime
